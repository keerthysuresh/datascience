# %%
# !pip install seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Displays the available datasets

# %%
sns.get_dataset_names()   #datasets title
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # to load the dataset

# %%
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # correlation

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# # Draw the heatmap to show the correlation

# %%
sns.heatmap(data.corr(),annot=True)     #annot=to show the values inside
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr(),annot=True,linewidth=4,cmap='RdGy_r',linecolor='k')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Univariate Distribution Analysis

# %% [markdown]
# distplot

# %% [markdown]
# Seaborn Distplot represents the overall distribution of continuous data variables. The Seaborn module along with the Matplotlib module is used to depict the distplot with different variations in it. The Distplot depicts the data by a histogram and a line in combination to it.

# %%
sns.distplot(data['sepal_length'])
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# # to get only hist

# %%
sns.distplot(data['sepal_length'],kde=False)      # kde-kernel density estimation
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length'>

# %% [markdown]
# # to get only curve

# %%
sns.distplot(data['sepal_length'],hist=False)
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# The analysis of two variables

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,dropna=True)   #scatter plot and marginal histogram, dropna= drop the null values

# %% [markdown]
# # different effects of kind

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='hex',dropna=True)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='reg',dropna=True)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='hist',dropna=True)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='resid',dropna=True)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='kde',dropna=True)

# %%
#additional keyword arguments

sns.jointplot(x='sepal_length',y='sepal_width',data=data,
              height=10,ratio=4,marker='*',marginal_kws=dict(bins=20,fill=True),dropna=True)

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,diag_kind='kde',hue='species')

# %% [markdown]
# # One categorical Variable- Stripplot

# %%
sns.stripplot(x='species',y='petal_length',jitter=True,data=data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.stripplot(x='species',y='petal_length',jitter=False,data=data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Swarmplot

# %% [markdown]
# accumulation illathe kittum

# %%
sns.swarmplot(data=data,x='species',y='petal_length')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Box Plot-Whisker plot

# %%
sns.boxplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=data,x='species',y='petal_length',fliersize=10,palette='Wistia_r')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=data,fliersize=12,palette='tab20b_r',orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Violin plot-Combination of boxplot and kde plot

# %%
sns.violinplot(data=data,palette='autumn',orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=data,x='species',y='petal_length',palette='autumn',inner='quartile')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='sepal_width',palette='autumn',inner='quartile',hue='species')# inner other options
                                                                                                      #stick and points
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',palette='autumn',inner='stick',hue='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,x='species',y='petal_length',palette='autumn',inner='points',hue='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(data=data,orient='v')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Count plot

# %%
sns.countplot('species',data=data)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # point plot

# %%
import seaborn as sns
sns.set_theme(style='darkgrid')
sns.pointplot(data=data,x='species',y='petal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.set_theme(style='ticks')
sns.pointplot(data=data,x='sepal_width',y='petal_length',hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %% [markdown]
# # Categorical Plot- earlier Factor Plot

# %%
sns.catplot(data=data,x='species',y='sepal_length',col='species',hue='species')

# %%
sns.catplot(data=data,x='species',y='petal_width',col='species',kind='swarm')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=data,x='species',y='petal_width',col='species',kind='box')

# %%
sns.catplot(data=data,x='species',y='petal_width',col='species',kind='violin')
