# %% [markdown]
# # what is feature scaling?

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/

# %% [raw]
# #Feature Engineering
# --------------------------
# 1:feature selection
# 2:Missing value handling
# 3:categorical value conversion- encoding
# 4:Feature scaling

# %% [raw]
# If feature scaling is not done, then a machine learning algorithm tends to weigh greater values, higher and consider smaller values as the lower values, regardless of the unit of the values.

# %% [markdown]
# Feature Scaling is a technique to standardize the independent features present in the data in a fixed range. It is performed during the data pre-processing.

# %% [markdown]
# Feature scaling is a family of statistical techniques that, as it name says,
# scales the features of our data so that they all have a similar range.

# %% [raw]
# Imagine we have data about the amount of money that our bank clients have,
# that goes in the 0–1000 $, and information about their age, that is in the 18–100 range

# %% [raw]
# Feature Scaling is done on the dataset to bring all the different types of data to a Single Format.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Main feature scaling techniques:

# %% [markdown]
# # Standardisation and Normalisation.

# %% [raw]
# # Normalisation/minmax  scales our features to a predefined range (normally the 0–1 range), independently of the statistical distribution they follow. It does this using the minimum and maximum values of each feature in our data set, which makes it a bit sensitive to outliers.

# %%
xi=5

xmax=5
xmin=2
x-normalised =3-2/5-2
# Out:
#   Input In [1]
#     x-normalised =3-2/5-2
#     ^
# SyntaxError: cannot assign to operator

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Standardisation takes our data and makes it follow a Normal distribution, usually of mean 0 and standard deviation 1.
# It is best to use it when we know our data follows an standard distribution or if we know there are many outliers.

# %% [markdown]
# standardization: It is a very effective technique which re-scales a feature value so that it has distribution with 0 mean value and variance equals to 1.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Package Used:
#     sklearn.preprocessing
#
# Import:
#      from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # These two techniques are called StandardScaler and MinMaxScaler.

# %%
#MinMax scaler(NORMALIZATION)

# %%
data = [[0,5],[2,13],[-3,7],[1,-4],[6,0]]
data
# Out:
# [[0, 5], [2, 13], [-3, 7], [1, -4], [6, 0]]

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler().fit(data)

print(mms.transform(data))   #the data points have been scaled to values between 0 and 1
# Out:
# [[0.33333333 0.52941176]
#  [0.55555556 1.        ]
#  [0.         0.64705882]
#  [0.44444444 0.        ]
#  [1.         0.23529412]]

# %%
mms = MinMaxScaler(feature_range=(-2,2)).fit(data)
print(mms.transform(data))
# Out:
# [[-0.66666667  0.11764706]
#  [ 0.22222222  2.        ]
#  [-2.          0.58823529]
#  [-0.22222222 -2.        ]
#  [ 2.         -1.05882353]]

# %%
#Standard Scaler//STANDARDIZATION

# %% [raw]
# Subtracting the mean from the data is called centering, whereas dividing by the standard deviation is called scaling.
# As such, the method is sometime called “center scaling“.

# %%
#Standard Scaler follows the Standard Normal Distribution, i.e., it assumes a normal distribution for data within each feature.
#The scaling makes the distribution centered around 0, with a standard deviation of 1 and mean=0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# 4 samples/observations and 2 variables/features
X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])

# the scaler object (model)
scaler = StandardScaler()

# fit and transform the data
scaled_data = scaler.fit_transform(X)
print(scaled_data)
# Out:
# [[-1. -1.]
#  [ 1. -1.]
#  [-1.  1.]
#  [ 1.  1.]]

# %% [markdown]
# # EXAMPLE 2 USING CARS DATA

# %%
import pandas as pd
df=pd.read_csv("CARSS.csv")
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo     1.0     790   99
# 1   Mitsubishi  Space Star     1.2    1160   95
# 2        Skoda      Citigo     1.0     929   95
# 3         Fiat         500     0.9     865   90
# 4         Mini      Cooper     1.5    1140  105
# 5           VW         Up!     1.0     929  105
# 6        Skoda       Fabia     1.4    1109   90
# 7     Mercedes     A-Class     1.5    1365   92
# 8         Ford      Fiesta     1.5    1112   98
# 9         Audi          A1     1.6    1150   99
# 10     Hyundai         I20     1.1     980   99
# 11      Suzuki       Swift     1.3     990  101
# 12        Ford      Fiesta     1.0    1112   99
# 13       Honda       Civic     1.6    1252   94
# 14      Hundai         I30     1.6    1326   97
# 15        Opel       Astra     1.6    1330   97
# 16         BMW           1     1.6    1365   99
# 17       Mazda           3     2.2    1280  104
# 18       Skoda       Rapid     1.6    1119  104
# ...

# %%
df.std()
# Out:
# Volume      0.388975
# Weight    242.123889
# CO2         7.454571
# dtype: float64

# %%
df.mean()
# Out:
# Volume       1.611111
# Weight    1292.277778
# CO2        102.027778
# dtype: float64

# %%
#It can be difficult to compare the volume 1.0 with the weight 790, but if we scale them both into comparable values,
#we can easily see how much one value is compared to the other.

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['Weight','Volume']]

scaledX = scale.fit_transform(X)
print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
# ...

# %%
scaled_column = pd.DataFrame(scaledX) 

df = pd.concat([df,scaled_column], axis = 1) 

df.rename(columns={0:"weight_Scaled",1:"volume_scaled"},inplace=True)
df
# Out:
#            Car       Model  Volume  Weight  CO2  weight_Scaled  volume_scaled
# 0       Toyoty        Aygo     1.0     790   99      -2.103893      -1.593366
# 1   Mitsubishi  Space Star     1.2    1160   95      -0.554072      -1.071901
# 2        Skoda      Citigo     1.0     929   95      -1.521663      -1.593366
# 3         Fiat         500     0.9     865   90      -1.789740      -1.854099
# 4         Mini      Cooper     1.5    1140  105      -0.637846      -0.289703
# 5           VW         Up!     1.0     929  105      -1.521663      -1.593366
# 6        Skoda       Fabia     1.4    1109   90      -0.767696      -0.550436
# 7     Mercedes     A-Class     1.5    1365   92       0.304612      -0.289703
# 8         Ford      Fiesta     1.5    1112   98      -0.755130      -0.289703
# 9         Audi          A1     1.6    1150   99      -0.595959      -0.028970
# 10     Hyundai         I20     1.1     980   99      -1.308039      -1.332634
# ...

# %% [markdown]
# # z = (x - u) / s

# %% [raw]
# #Where z is the new value, x is the original value, u is the mean and s is the standard deviation.
#
# If you take the weight column from the data set above, the first value is 790, and the scaled value will be:
#
# (790 - 1292.23) / 238.74 = -2.1
#
# similarly if we consider the volume column.the first value is 1.0,which when applied the above formulae gives"
# (1.0-1.611111)/0.388975= -1.5

# %% [markdown]
# # Now you can compare -2.1 with -1.59 instead of comparing 790 with 1.0.

# %% [markdown]
# # MinMaxScaler

# %%
import seaborn as sns

# %%
iris=sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
X = iris.iloc[:,0:4]
y = iris.iloc[:,4]
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler

scaled_x= MinMaxScaler().fit_transform(X)

# %%
scaled_x #range btwn 0 and 1
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
scaled_column =pd.DataFrame(scaled_x)

df = pd.concat([iris,scaled_column], axis = 1)

df.rename(columns={0:'sl_scaled',1:'Sw_scaled',2:'pl_scaled',3:'pw_scaled'},inplace=True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sl_scaled  Sw_scaled  pl_scaled  pw_scaled
# 0     0.222222   0.625000   0.067797   0.041667
# ...
