# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sns.distplot(df["YearsExperience"],hist=False)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsExperience', ylabel='Density'>

# %%
sns.set(rc={"figure.figsize":(10,10)})
sns.countplot(y="YearsExperience",data=df,orient="h")
# Out:
# <AxesSubplot:xlabel='count', ylabel='YearsExperience'>

# %%
sns.pairplot(df)

# %%
X=df.iloc[:,:-1].values
X         #x always 2d,y epozhum 1d.ella columthile -1 vare means 0 mathram
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
Y=df.iloc[:,1].values
Y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=1/3,random_state=4)

# %%
X_train
# Out:
# array([[2. ],
#        [5.1],
#        [3.9],
#        [3. ],
#        [4. ],
#        [1.5],
#        [2.2],
#        [7.9],
#        [4.1],
#        [3.2],
#        [3.7],
#        [5.9],
#        [8.7],
#        [9.6],
#        [3.2],
#        [1.3],
#        [2.9],
#        [8.2],
#        [4.5],
#        [9.5]])

# %%
X_test
# Out:
# array([[ 4. ],
#        [ 7.1],
#        [10.3],
#        [ 4.9],
#        [ 6.8],
#        [ 9. ],
#        [ 5.3],
#        [10.5],
#        [ 6. ],
#        [ 1.1]])

# %%
Y_train
# Out:
# array([ 43525.,  66029.,  63218.,  60150.,  56957.,  37731.,  39891.,
#        101302.,  57081.,  54445.,  57189.,  81363., 109431., 112635.,
#         64445.,  46205.,  56642., 113812.,  61111., 116969.])

# %%
Y_test
# Out:
# array([ 55794.,  98273., 122391.,  67938.,  91738., 105582.,  83088.,
#        121872.,  93940.,  39343.])

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)
Y_pred
# Out:
# array([ 63116.62489678,  92781.58020231, 123403.46954996,  71729.03127581,
#         89910.77807597, 110963.32700248,  75556.76744426, 125317.33763419,
#         82255.30573906,  35365.53767547])

# %%
plt.scatter(X_train,Y_train,color="blue")

plt.plot(X_train,lr.predict(X_train),color="red")

plt.title("salary-Experience(traintest)")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(X_test,Y_test,color="yellow")

plt.plot(X_test,lr.predict(X_test),color="red")

plt.title("salary-Experience(traintest)")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()

# %%
from sklearn import metrics 

print("MAE:",metrics.mean_absolute_error(Y_test,Y_pred))
print("MsE:",metrics.mean_squared_error(Y_test,Y_pred))
print("RMSE:",np.sqrt(metrics.mean_absolute_error(Y_test,Y_pred)))
# Out:
# MAE: 5146.482122213041
# MsE: 35241306.15012057
# RMSE: 71.73898606903391

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Mean Squared Error (MSE) or Mean Squared Deviation (MSD) of an estimator measures the average of error squares i.e. the average squared difference between the estimated values and true value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Y_pred=lr.predict(X_test)
Y_pred
# Out:
# array([ 63116.62489678,  92781.58020231, 123403.46954996,  71729.03127581,
#         89910.77807597, 110963.32700248,  75556.76744426, 125317.33763419,
#         82255.30573906,  35365.53767547])

# %%
Y_test
# Out:
# array([ 55794.,  98273., 122391.,  67938.,  91738., 105582.,  83088.,
#        121872.,  93940.,  39343.])

# %%
Y_pred1=lr.predict([[15]])    #future prediction
Y_pred1
# Out:
# array([168379.36952931])

# %%
data=pd.DataFrame(Y_pred)
data
# Out:
#                0
# 0   63116.624897
# 1   92781.580202
# 2  123403.469550
# 3   71729.031276
# 4   89910.778076
# 5  110963.327002
# 6   75556.767444
# 7  125317.337634
# 8   82255.305739
# 9   35365.537675

# %%
datanew=pd.concat([data,df],axis=1)
datanew
# Out:
#                 0  YearsExperience    Salary
# 0    63116.624897              1.1   39343.0
# 1    92781.580202              1.3   46205.0
# 2   123403.469550              1.5   37731.0
# 3    71729.031276              2.0   43525.0
# 4    89910.778076              2.2   39891.0
# 5   110963.327002              2.9   56642.0
# 6    75556.767444              3.0   60150.0
# 7   125317.337634              3.2   54445.0
# 8    82255.305739              3.2   64445.0
# 9    35365.537675              3.7   57189.0
# 10            NaN              3.9   63218.0
# 11            NaN              4.0   55794.0
# 12            NaN              4.0   56957.0
# 13            NaN              4.1   57081.0
# 14            NaN              4.5   61111.0
# 15            NaN              4.9   67938.0
# 16            NaN              5.1   66029.0
# 17            NaN              5.3   83088.0
# 18            NaN              5.9   81363.0
# 19            NaN              6.0   93940.0
# ...

# %%
datanew.rename(columns={0:"Y_pred"},inplace=True)
datanew
# Out:
#            Y_pred  YearsExperience    Salary
# 0    63116.624897              1.1   39343.0
# 1    92781.580202              1.3   46205.0
# 2   123403.469550              1.5   37731.0
# 3    71729.031276              2.0   43525.0
# 4    89910.778076              2.2   39891.0
# 5   110963.327002              2.9   56642.0
# 6    75556.767444              3.0   60150.0
# 7   125317.337634              3.2   54445.0
# 8    82255.305739              3.2   64445.0
# 9    35365.537675              3.7   57189.0
# 10            NaN              3.9   63218.0
# 11            NaN              4.0   55794.0
# 12            NaN              4.0   56957.0
# 13            NaN              4.1   57081.0
# 14            NaN              4.5   61111.0
# 15            NaN              4.9   67938.0
# 16            NaN              5.1   66029.0
# 17            NaN              5.3   83088.0
# 18            NaN              5.9   81363.0
# 19            NaN              6.0   93940.0
# ...

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
