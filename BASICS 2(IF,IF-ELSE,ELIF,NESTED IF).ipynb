# %% [markdown]
# # Python Conditions

# %% [markdown]
# Python supports the usual logical conditions from mathematics:
#     Equals:a==b
#
#     Not equals:a!=b
#
#     Less than: a<b
#
#     Less than or equal to:a<=b
#
#     Greater than: a>b
#
#     Greater than or equal:a>=b
#
#     These conditions can be used in several ways,most commonly in"if statements" and loops.

# %% [markdown]
# # IF STATEMENT
# # An "if statement"is written by using the if keyword

# %%
#eg:
a=23
b=33
if b>a:
    
    
    print('b is greater than a')
# Out:
#   Cell In[2], line 5
#     rtyhj
#     ^
# IndentationError: expected an indented block

# %%
a=23
b=35
if (a<b):
    print('a is less than b')
# Out:
# a is less than b

# %%
#python relies on indentation(white space at the beginning of a line) to define space in the code
a=33
b=200
if (b>a):print('b is greater than a')
    
    # w/o the space we will get an error
# Out:
# b is greater than a

# %%
i=7
if(i<15):
    
    print('14 s less than 15')
    print("I am not if")
# Out:
# 14 s less than 15
# I am not if

# %%
a=1
b=10
if a<b:print('a is greater than b')           #we can write it in same line
# Out:
# a is greater than b

# %% [markdown]
# # IF-ELSE Statement

# %%
#eg
i=5

if(i<15):
    i=i+6 
    print(i)
    
    print('i is smallerthan 15')
    print("i'm in if Block" )

else:
    print("20 is greater than 15")
    print("i'm in else Block")
print("i'm not in if and else Block")
# Out:
# 11
# i is smallerthan 15
# i'm in if Block
# i'm not in if and else Block

# %%
i=2
if(i<15):
    i=i+1
    print(i)
    print('i is smallerthan 15')
    print("i'm in if Block" )
else:
    print("i is greater than 15")
    print("i'm in else Block")
print("i'm not in if and else Block")
# Out:
# 3
# i is smallerthan 15
# i'm in if Block
# i'm not in if and else Block

# %% [markdown]
# # ELIF Statement

# %% [markdown]
# ![Python-elif-Statement-Syntax.jpg](attachment:Python-elif-Statement-Syntax.jpg)

# %% [markdown]
# ![Python_if_elif_else_statement.jpg](attachment:Python_if_elif_else_statement.jpg)

# %%
#eg
a=4
if a<0:
    print(a,"is negative")
elif a==0:
    print("its a 0")
elif a>0 and a<5:         #checking whether a is between 0 and 5
    print(a,"is b/w(0 and 5)")
else:
    print(a,"equals or greater than 5")
# Out:
# 4 is b/w(0 and 5)

# %%
day=int(input('enter weekday day number(1-7):'))#eval
if day==1:
    print("\nmonday")
elif day==2:
    print("\ntuesday")
elif day==3:
    print("\nwednesday")
elif day==4:
    print("\nthursday")
elif day==5:
    print("\nfriday")
elif day==6:
    print("\nsaturday")
elif day==7:
    print("\nsunday")
else:
    print("\n please enter weekdaynumber b/w 1 to 7")
# Out:
# enter weekday day number(1-7):6
#
# saturday

# %%
user=eval(input('enter a number '))
user
# Out:
# enter a number 9.0
# 9.0

# %%
type(user)
# Out:
# float

# %%
print('hai\n         hello')
# Out:
# hai
#          hello

# %% [markdown]
# # Nested if

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#eg
age=eval(input('enter the age'))
isGraduated = False
hasLicense = True
#Look if person is 18 years or older
if age >=18:
    print("you are 18 or older.Welcome to adulthood")
    if isGraduated:
        print("Congratulations with your graduation")
    else:
        print("not graduated")
    if hasLicense:
        print('Happy driving')
    else:
        print('get license')
else:
    print("ineligible")
# Out:
# enter the age4
# ineligible
